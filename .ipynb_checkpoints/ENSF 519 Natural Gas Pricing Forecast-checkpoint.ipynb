# %% [markdown]
# # ENSF 519.01 Applied Data Science
# **Final Project - Prediciting Alberta Natural Gas Prices using Machine Learning**
#
# **Due:** Sometime in December
#
#
# **Team Members:**
# James Bews,
# Kendal Blais,
# Tevin Schmidt,
# Peter Schulze,

# %% [markdown]
# **Phase I:** Collect, Integrate and Clean data
#
#
# **Data Collection**

# %%
import pandas as pd

# aggregate consumption
cad_data = pd.read_csv('CAD_NatGasSupply_Monthly.csv', thousands=',').rename(columns={'Month': 'Date'}).set_index('Date') # volumes in cubic meters
us_prod_data = pd.read_csv('US_NatGasProd_Monthly.csv').set_index('Date') # volumes in MMcf
us_demand_data = pd.read_csv('US_NatGasDemand_Monthly.csv').set_index('Date').dropna() # volumes in MMcf
price_data = pd.read_csv('US_CAN_NatGas_Prices.csv').set_index('Date') # prices in USD

# %%
from bs4 import BeautifulSoup
import requests

storage_stats_url = 'https://www150.statcan.gc.ca/t1/tbl1/en/cv!recreate.action?pid=2510005701&selectedNodeIds=2D2,3D1&checkedLevels=0D1&refPeriods=20160101,20190801&dimensionLayouts=layout2,layout3,layout2,layout2&vectorDisplay=false'

def get_page_html(url):
    return requests.get(url,timeout=10)

storage_stats_html = get_page_html(storage_stats_url).content
storage_stats_html
# Out:
# D1","level":2,"controlType":false},{"id":"1D4","text":"Saskatchewan [47]","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":1,"memberId":4,"displayOrder":4,"parentId":1,"parentNodeId":"1D1","level":2,"controlType":false},{"id":"1D5","text":"Alberta [48]","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":1,"memberId":5,"displayOrder":5,"parentId":1,"parentNodeId":"1D1","level":2,"controlType":false},{"id":"1D6","text":"British Columbia [59]","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":1,"memberId":6,"displayOrder":6,"parentId":1,"parentNodeId":"1D1","level":2,"controlType":false},{"id":"2D1","text":"Opening inventory","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":2,"memberId":1,"displayOrder":1,"parentId":0,"parentNodeId":null,"level":1,"controlType":false},{"id":"2D2","text":"Closing inventory","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":2,"memberId":2,"displayOrder":2,"parentId":0,"parentNodeId":null,"level":1,"controlType":false},{"id":"2D3","text":"Inventory change","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":2,"memberId":3,"displayOrder":3,"parentId":0,"parentNodeId":null,"level":1,"controlType":false},{"id":"2D4","text":"Injections to storage","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":2,"memberId":4,"displayOrder":4,"parentId":0,"parentNodeId":null,"level":1,"controlType":false},{"id":"2D5","text":"Withdrawals from storage","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":2,"memberId":5,"displayOrder":5,"parentId":0,"parentNodeId":null,"level":1,"controlType":false},{"id":"2D6","text":"Other adjustments","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":2,"memberId":6,"displayOrder":6,"parentId":0,"parentNodeId":null,"level":1,"controlType":false},{"id":"3D1","text":"Cubic metres","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":3,"memberId":1,"displayOrder":1,"parentId":0,"parentNodeId":null,"level":1,"controlType":false},{"id":"3D2","text":"Gigajoules","icon":null,"state":{"opened":false,"disabled":false,"selected":false},"children":[],"li_attr":null,"a_attr":null,"type":null,"cubePid":25100057,"dimensionSequence":3,"memberId":2,"displayOrder":2,"parentId":0,"parentNodeId":null,"level":1,"controlType":false}];\r\n    let viewInfoJson = {"_id":"2510005701","type":"view","checkedLevel":[],"cubePid":25100057,"viewDimensionDbs":[{"sequenceNumber":1,"dimensionLocationId":1,"dimensionLocation":"Dropdown","viewMemberDbs":[{"memberId":1,"special":true},{"memberId":2,"special":false},{"memberId":3,"special":false},{"memberId":4,"special":false},{"memberId":5,"special":false},{"memberId":6,"special":false}]},{"sequenceNumber":2,"dimensionLocationId":3,"dimensionLocation":"Row","viewMemberDbs":[{"memberId":1,"special":true},{"memberId":2,"special":false},{"memberId":3,"special":false},{"memberId":4,"special":false},{"memberId":5,"special":false},{"memberId":6,"special":fa ...

# %%
parser = BeautifulSoup(storage_stats_html, 'html.parser')

column_name_selector = '.pub-table .uom-center.bold'
columns = list(map(lambda elem: elem.text, parser.select(column_name_selector)))[2:]

row_name_selector = '.pub-table .highlight-row .align-right'
row = list(map(lambda elem: [float(elem.text.replace(',', ''))], parser.select(row_name_selector)))

storage_stats_dict = dict(zip(columns, row))
storage_stats_df = pd.DataFrame(storage_stats_dict)
# storage_stats_df contains closing inventory of a given month in cubic meters
storage_stats_df
# Out:
#    January 2016  February 2016  March 2016  April 2016    May 2016  \
# 0    22220401.0     20472652.0  21006678.0  21036484.0  22392448.0
#
#     June 2016   July 2016  August 2016  September 2016  October 2016  ...  \
# 0  23743852.0  24585440.0   26122336.0      27420813.0    27234246.0  ...
#
#    November 2018  December 2018  January 2019  February 2019  March 2019  \
# 0     24072620.0     22871032.0    19196970.0     15318116.0  13874110.0
#
#    April 2019    May 2019   June 2019   July 2019  August 2019
# 0  14142153.0  15744979.0  17643177.0  19187741.0   21098047.0
#
# [1 rows x 44 columns]

# %% [markdown]
# **Data Preparation**
#
# - Volumes must be converted to MMcf
# - USD must be convetred to CAD

# %%
# Aggregate CAD Consumption
cad_data['CAD Natural Gas Consumption'] = cad_data['Residential consumption']+cad_data['Commercial consumption']+cad_data['Industrial consumption']
cad_data = cad_data.drop(['Gross withdrawals','Imports','Residential consumption', 'Industrial consumption', 'Commercial consumption', 'Exports', 'Opening inventory', 'Closing inventory', 'Inventory change'], axis=1)
cad_data
# Out:
#         Marketable production  CAD Natural Gas Consumption
# Date
# Jan-16             14289542.7                   11065298.7
# Feb-16             13607932.1                    9863883.1
# Mar-16             14421808.5                    9690121.5
# Apr-16             13104382.7                    7982794.7
# May-16             14139484.9                    6616912.9
# Jun-16             13477340.2                    7354024.2
# Jul-16             13928637.2                    7725783.2
# Aug-16             14248386.5                    7710188.5
# Sep-16             13546045.8                    6258890.8
# Oct-16             13878269.8                    7428673.8
# Nov-16             13812936.7                    8528667.7
# Dec-16             14707574.5                   10843597.5
# Jan-17             15045933.0                   11551996.0
# Feb-17             13541884.2                   10223378.2
# Mar-17             15123152.3                   10695500.3
# Apr-17             14241893.7                    8614249.7
# May-17             14420961.4                    7341382.4
# Jun-17             13542113.6                    7099728.6
# Jul-17             14283181.6                    8016599.6
# Aug-17             14138683.2                    8108976.2
# Sep-17             13976778.7                    7057917.7
# Oct-17             14667567.7                    7772413.7
# Nov-17             15009876.1                    9744503.1
# Dec-17             15482803.5                   12135840.5
# Jan-18             15695290.5                   13144586.5
# Feb-18             13995594.8                   11888311.8
# Mar-18             15638124.4                   11760799.4
# Apr-18             14930065.7                   10045068.7
# May-18             14694411.2                    8351332.2
# Jun-18             14130132.4                    7403921.4
# Jul-18             14860499.8                    7388179.8
# Aug-18             14814375.6                    7459264.6
# Sep-18             14233046.4                    7509526.4
# Oct-18             14712349.3                    8588861.3
# Nov-18             14440102.5                   10115522.5
# Dec-18             15676951.8                   11677398.8
# Jan-19             15081541.6                   13556673.6
# Feb-19             13259939.1                   13162741.1
# Mar-19             15181902.3                   12607273.3
# Apr-19             14388994.4                   10069566.4
# May-19             14268140.9                    8537621.9
# Jun-19             13502472.8                    7758097.8
# Jul-19             14157362.7                    7643799.7
# Aug-19             14062328.7                    7698214.7

# %% [markdown]
# **Data Exploration**

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

ax = plt.gca()
cad_data.plot(kind='line', y='Marketable production', ax=ax)
plt.show()

# %%
ax = plt.gca()
cad_data.plot(kind='line', y='CAD Natural Gas Consumption', ax=ax)
plt.show()

# %%
#US Production
ax = plt.gca()
us_prod_data.plot(kind='line', y='U.S. Dry Natural Gas Production (MMcf)', ax=ax)
plt.show()

# %%
#US Demand
ax = plt.gca()
us_demand_data.plot(kind='line', y='U.S. Natural Gas Total Consumption (MMcf)', ax=ax)
plt.show()

# %%
# AECO Nat Gas Pricing
ax = plt.gca()
price_data.plot(kind='line', y='AECO (USD/MMBtu)', ax=ax)
plt.show()

# %% [markdown]
# **Data Prediction**
